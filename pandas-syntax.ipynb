# %%
import nltk
import pandas as pd
from nltk.tokenize import regexp_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
file_location = 'C:/Users/Garima/Desktop/dev.csv'

# %%
file_dev=pd.read_csv(file_location)
df=pd.read_csv(file_location)

# %%
file_dev.to_csv('file_dev.csv', index=False)
df=pd.read_csv(file_location)

# %%
file_dev = pd.read_csv('file_dev.csv')
df=pd.read_csv('file_dev.csv')

# %%
file_dev['Correct Statement'] = file_dev['Correct Statement'].str.lower()
file_dev['Incorrect Statement'] = file_dev['Incorrect Statement'].str.lower()
file_dev['Right Reason1'] = file_dev['Right Reason1'].str.lower()
file_dev['Confusing Reason1'] = file_dev['Confusing Reason1'].str.lower()
file_dev['Confusing Reason2'] = file_dev['Confusing Reason2'].str.lower()
file_dev['Right Reason2'] = file_dev['Right Reason2'].str.lower()
file_dev['Right Reason3'] = file_dev['Right Reason3'].str.lower()

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–"]

# %%
for char in spec_chars:
    file_dev['Correct Statement'] = file_dev['Correct Statement'].str.replace(char, ' ')
    file_dev['Incorrect Statement'] = file_dev['Incorrect Statement'].str.replace(char, ' ')
    file_dev['Right Reason1'] = file_dev['Right Reason1'].str.replace(char, ' ')
    file_dev['Confusing Reason1'] = file_dev['Confusing Reason1'].str.replace(char, ' ')
    file_dev['Confusing Reason2'] = file_dev['Confusing Reason2'].str.replace(char, ' ')
    file_dev['Right Reason2'] = file_dev['Right Reason2'].str.replace(char, ' ')
    file_dev['Right Reason3'] = file_dev['Right Reason3'].str.replace(char, ' ')
# Out:
# <ipython-input-137-e58f035ec9c4>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   file_dev['Correct Statement'] = file_dev['Correct Statement'].str.replace(char, ' ')
# <ipython-input-137-e58f035ec9c4>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   file_dev['Incorrect Statement'] = file_dev['Incorrect Statement'].str.replace(char, ' ')
# <ipython-input-137-e58f035ec9c4>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   file_dev['Right Reason1'] = file_dev['Right Reason1'].str.replace(char, ' ')
# ...

# %%
file_dev.dtypes
# Out:
# Correct Statement      object
# Incorrect Statement    object
# Right Reason1          object
# Confusing Reason1      object
# Confusing Reason2      object
# Right Reason2          object
# Right Reason3          object
# dtype: object

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Garima\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
file_dev['Correct Statement'] = file_dev['Correct Statement'].astype(str)
file_dev['Incorrect Statement'] = file_dev['Incorrect Statement'].astype(str)
file_dev['Right Reason1'] = file_dev['Right Reason1'].astype(str)
file_dev['Confusing Reason1'] = file_dev['Confusing Reason1'].astype(str)
file_dev['Right Reason2'] = file_dev['Right Reason2'].astype(str)
file_dev['Confusing Reason2'] = file_dev['Confusing Reason2'].astype(str)
file_dev['Right Reason3'] = file_dev['Right Reason3'].astype(str)

# %%
file_dev['Correct Statement']
file_dev['tokenized_Correct_sents'] = file_dev.apply(lambda row: nltk.word_tokenize(row['Correct Statement']), axis=1)
file_dev=file_dev.drop(['Correct Statement'], axis = 1)
file_dev['Incorrect Statement']
file_dev['tokenized_Incorrect Statement'] = file_dev.apply(lambda row: nltk.word_tokenize(row['Incorrect Statement']), axis=1)
file_dev=file_dev.drop(['Incorrect Statement'], axis = 1)
file_dev['Right Reason1']
file_dev['tokenized_Right Reason1'] = file_dev.apply(lambda row: nltk.word_tokenize(row['Right Reason1']), axis=1)
file_dev=file_dev.drop(['Right Reason1'], axis = 1)
file_dev['Confusing Reason1']
file_dev['tokenized_Confusing Reason1'] = file_dev.apply(lambda row: nltk.word_tokenize(row['Confusing Reason1']), axis=1)
file_dev=file_dev.drop(['Confusing Reason1'], axis = 1)
file_dev['Right Reason2']
file_dev['tokenized_Right Reason2'] = file_dev.apply(lambda row: nltk.word_tokenize(row['Right Reason2']), axis=1)
file_dev=file_dev.drop(['Right Reason2'], axis = 1)
file_dev['Confusing Reason2']
file_dev['tokenized_Confusing Reason2'] = file_dev.apply(lambda row: nltk.word_tokenize(row['Confusing Reason2']), axis=1)
file_dev=file_dev.drop(['Confusing Reason2'], axis = 1)
file_dev['Right Reason3']
file_dev['tokenized_Right Reason3'] = file_dev.apply(lambda row: nltk.word_tokenize(row['Right Reason3']), axis=1)
file_dev=file_dev.drop(['Right Reason3'], axis = 1)
file_dev.head(2)
# Out:
#                    tokenized_Correct_sents  \
# 0  [a, chainsaw, is, used, to, cut, trees]
# 1              [the, closet, got, hangers]
#
#                 tokenized_Incorrect Statement  \
# 0  [a, chainsaw, is, used, to, cut, diamonds]
# 1         [the, hangers, bought, the, closet]
#
#                              tokenized_Right Reason1  \
# 0  [cutting, diamonds, with, a, chainsaw, would, ...
# 1  [hangers, are, inanimate, things, which, can, ...
#
#                          tokenized_Confusing Reason1  \
# 0  [chainsaw, are, produced, from, the, factory, ...
# 1  [a, hanger, is, something, you, put, your, clo...
#
#                tokenized_Right Reason2          tokenized_Confusing Reason2  \
# 0  [diamonds, don, t, grow, on, trees]  [diamonds, don, t, grow, on, trees]
# 1        [the, hangers, can, not, eat]        [the, hangers, can, not, eat]
#
#                    tokenized_Right Reason3
# 0  [chainsaws, arent, used, for, diamonds]
# ...

# %%
from nltk.stem import PorterStemmer
stemming = PorterStemmer()

# %%
def stem_list(row):
    my_list = row['tokenized_Correct_sents']
    stemmed_list = [stemming.stem(word) for word in my_list]
    return (stemmed_list)

file_dev['stemmed_Correct_sents'] = file_dev.apply(stem_list, axis=1)

# %%
file_dev['stemmed_Correct_sents']
# Out:
# 0                  [a, chainsaw, is, use, to, cut, tree]
# 1                             [the, closet, got, hanger]
# 2                                  [a, pillow, is, soft]
# 3        [straight, razor, are, great, for, trim, beard]
# 4      [you, are, like, to, find, an, orang, tree, in...
#                              ...
# 995      [heat, energi, can, convert, to, light, energi]
# 996                      [he, ride, a, bicycl, on, road]
# 997        [the, boy, wore, uniform, to, go, to, school]
# 998                     [my, brother, is, drive, a, car]
# 999                      [he, use, fire, to, cook, food]
# Name: stemmed_Correct_sents, Length: 1000, dtype: object

# %%
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['stemmed_Correct_sents']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

file_dev['stop_Correct_sents'] = file_dev.apply(remove_stops, axis=1)

# %%
file_dev['stop_Correct_sents']
# Out:
# 0                  [chainsaw, use, cut, tree]
# 1                       [closet, got, hanger]
# 2                              [pillow, soft]
# 3       [straight, razor, great, trim, beard]
# 4          [like, find, orang, tree, florida]
#                         ...
# 995    [heat, energi, convert, light, energi]
# 996                      [ride, bicycl, road]
# 997          [boy, wore, uniform, go, school]
# 998                     [brother, drive, car]
# 999                   [use, fire, cook, food]
# Name: stop_Correct_sents, Length: 1000, dtype: object

# %%
def stem_list(row):
    my_list = row['tokenized_Incorrect Statement']
    stemmed_list = [stemming.stem(word) for word in my_list]
    return (stemmed_list)

file_dev['stemmed_Incorrect Statement'] = file_dev.apply(stem_list, axis=1)

# %%
file_dev['stemmed_Incorrect Statement']
# Out:
# 0               [a, chainsaw, is, use, to, cut, diamond]
# 1                     [the, hanger, bought, the, closet]
# 2                    [feather, in, a, pillow, are, hard]
# 3      [straight, razor, are, great, for, cut, sheet,...
# 4      [you, are, like, to, find, an, orang, tree, in...
#                              ...
# 995    [lamp, can, convert, peanut, butter, for, energi]
# 996                     [he, ride, a, bicycl, on, water]
# 997       [the, boy, wore, uniform, to, go, to, restaur]
# 998                      [my, giraff, is, drive, a, car]
# 999                     [he, use, water, to, cook, food]
# Name: stemmed_Incorrect Statement, Length: 1000, dtype: object

# %%
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['stemmed_Incorrect Statement']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

file_dev['stop_Incorrect Statement'] = file_dev.apply(remove_stops, axis=1)

# %%
file_dev['stop_Incorrect Statement']
# Out:
# 0                    [chainsaw, use, cut, diamond]
# 1                         [hanger, bought, closet]
# 2                          [feather, pillow, hard]
# 3      [straight, razor, great, cut, sheet, metal]
# 4            [like, find, orang, tree, antarctica]
#                           ...
# 995        [lamp, convert, peanut, butter, energi]
# 996                          [ride, bicycl, water]
# 997              [boy, wore, uniform, go, restaur]
# 998                           [giraff, drive, car]
# 999                       [use, water, cook, food]
# Name: stop_Incorrect Statement, Length: 1000, dtype: object

# %%
file_dev=file_dev.drop(['tokenized_Correct_sents'], axis = 1)
file_dev=file_dev.drop(['stemmed_Correct_sents'], axis = 1)
file_dev=file_dev.drop(['tokenized_Incorrect Statement'], axis = 1)
file_dev=file_dev.drop(['stemmed_Incorrect Statement'], axis = 1)

# %%
def stem_list(row):
    my_list = row['tokenized_Right Reason1']
    stemmed_list = [stemming.stem(word) for word in my_list]
    return (stemmed_list)

file_dev['stemmed_Right Reason1'] = file_dev.apply(stem_list, axis=1)
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['stemmed_Right Reason1']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

file_dev['stop_Right Reason1'] = file_dev.apply(remove_stops, axis=1)
file_dev=file_dev.drop(['tokenized_Right Reason1'], axis = 1)
file_dev=file_dev.drop(['stemmed_Right Reason1'], axis = 1)

# %%
def stem_list(row):
    my_list = row['tokenized_Confusing Reason1']
    stemmed_list = [stemming.stem(word) for word in my_list]
    return (stemmed_list)

file_dev['stemmed_Confusing Reason1'] = file_dev.apply(stem_list, axis=1)
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['stemmed_Confusing Reason1']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

file_dev['stop_Confusing Reason1'] = file_dev.apply(remove_stops, axis=1)
file_dev=file_dev.drop(['tokenized_Confusing Reason1'], axis = 1)
file_dev=file_dev.drop(['stemmed_Confusing Reason1'], axis = 1)

# %%
def stem_list(row):
    my_list = row['tokenized_Right Reason2']
    stemmed_list = [stemming.stem(word) for word in my_list]
    return (stemmed_list)

file_dev['stemmed_Right Reason2'] = file_dev.apply(stem_list, axis=1)
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['stemmed_Right Reason2']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

file_dev['stop_Right Reason2'] = file_dev.apply(remove_stops, axis=1)
file_dev=file_dev.drop(['tokenized_Right Reason2'], axis = 1)
file_dev=file_dev.drop(['stemmed_Right Reason2'], axis = 1)

# %%
file_dev
# Out:
#                            tokenized_Confusing Reason2  \
# 0                  [diamonds, don, t, grow, on, trees]
# 1                        [the, hangers, can, not, eat]
# 2                  [feathers, have, different, shapes]
# 3    [sheet, metal, is, lighter, than, straight, ra...
# 4    [that, pile, of, snow, in, antarctica, seems, ...
# ..                                                 ...
# 995                [the, lamp, looks, like, a, peanut]
# 996  [there, is, an, image, of, water, on, the, bic...
# 997              [restaurants, don, t, sell, uniforms]
# 998                [a, giraffe, can, not, eat, a, car]
# 999   [fire, is, hot, but, water, is, cold, generally]
#
#                                tokenized_Right Reason3  \
# 0              [chainsaws, arent, used, for, diamonds]
# 1                         [hangers, dont, have, money]
# 2    [feathers, are, soft, as, people, want, pillow...
# 3    [straight, razors, are, only, used, for, shavi...
# ...

# %%
def stem_list(row):
    my_list = row['tokenized_Confusing Reason2']
    stemmed_list = [stemming.stem(word) for word in my_list]
    return (stemmed_list)

file_dev['stemmed_Confusing Reason2'] = file_dev.apply(stem_list, axis=1)
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['stemmed_Confusing Reason2']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

file_dev['stop_Confusing Reason2'] = file_dev.apply(remove_stops, axis=1)
file_dev=file_dev.drop(['tokenized_Confusing Reason2'], axis = 1)
file_dev=file_dev.drop(['stemmed_Confusing Reason2'], axis = 1)

# %%
file_dev
# Out:
#                                tokenized_Right Reason3  \
# 0              [chainsaws, arent, used, for, diamonds]
# 1                         [hangers, dont, have, money]
# 2    [feathers, are, soft, as, people, want, pillow...
# 3    [straight, razors, are, only, used, for, shavi...
# 4    [it, is, too, cold, in, antarctica, for, an, o...
# ..                                                 ...
# 995  [peanut, butter, is, an, eatable, and, can, no...
# 996        [bicycles, can, not, be, ridden, on, water]
# 997  [restaurants, do, not, require, uniform, for, ...
# 998  [giraffes, could, not, fit, in, a, car, nor, c...
# 999       [water, must, be, very, hot, to, cook, food]
#
#                          stop_Correct_sents  \
# 0                [chainsaw, use, cut, tree]
# 1                     [closet, got, hanger]
# 2                            [pillow, soft]
# 3     [straight, razor, great, trim, beard]
# 4        [like, find, orang, tree, florida]
# ...

# %%
def stem_list(row):
    my_list = row['tokenized_Right Reason3']
    stemmed_list = [stemming.stem(word) for word in my_list]
    return (stemmed_list)

file_dev['stemmed_Right Reason3'] = file_dev.apply(stem_list, axis=1)
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['stemmed_Right Reason3']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

file_dev['stop_Right Reason3'] = file_dev.apply(remove_stops, axis=1)
file_dev=file_dev.drop(['tokenized_Right Reason3'], axis = 1)
file_dev=file_dev.drop(['stemmed_Right Reason3'], axis = 1)

# %%
file_dev
# Out:
#                          stop_Correct_sents  \
# 0                [chainsaw, use, cut, tree]
# 1                     [closet, got, hanger]
# 2                            [pillow, soft]
# 3     [straight, razor, great, trim, beard]
# 4        [like, find, orang, tree, florida]
# ..                                      ...
# 995  [heat, energi, convert, light, energi]
# 996                    [ride, bicycl, road]
# 997        [boy, wore, uniform, go, school]
# 998                   [brother, drive, car]
# 999                 [use, fire, cook, food]
#
#                         stop_Incorrect Statement  \
# 0                  [chainsaw, use, cut, diamond]
# 1                       [hanger, bought, closet]
# 2                        [feather, pillow, hard]
# 3    [straight, razor, great, cut, sheet, metal]
# 4          [like, find, orang, tree, antarctica]
# ..                                           ...
# 995      [lamp, convert, peanut, butter, energi]
# ...

# %%
def rejoin_words(row):
    my_list = row['stop_Correct_sents']
    joined_words = ( " ".join(my_list))
    return joined_words

file_dev['processed_Correct_sents'] = file_dev.apply(rejoin_words, axis=1)
file_dev=file_dev.drop(['stop_Correct_sents'], axis = 1)
file_dev
# Out:
#                         stop_Incorrect Statement  \
# 0                  [chainsaw, use, cut, diamond]
# 1                       [hanger, bought, closet]
# 2                        [feather, pillow, hard]
# 3    [straight, razor, great, cut, sheet, metal]
# 4          [like, find, orang, tree, antarctica]
# ..                                           ...
# 995      [lamp, convert, peanut, butter, energi]
# 996                        [ride, bicycl, water]
# 997            [boy, wore, uniform, go, restaur]
# 998                         [giraff, drive, car]
# 999                     [use, water, cook, food]
#
#                                     stop_Right Reason1  \
# 0               [cut, diamond, chainsaw, would, break]
# 1                 [hanger, inanim, thing, buy, someth]
# 2                               [feather, alway, soft]
# 3    [blade, straight, razor, thin, cut, sheet, metal]
# 4                [cold, orang, tree, grow, antarctica]
# ...

# %%
def rejoin_words(row):
    my_list = row['stop_Right Reason1']
    joined_words = ( " ".join(my_list))
    return joined_words

file_dev['processed_Right Reason1'] = file_dev.apply(rejoin_words, axis=1)
file_dev=file_dev.drop(['stop_Right Reason1'], axis = 1)
file_dev
# Out:
#                         stop_Incorrect Statement  \
# 0                  [chainsaw, use, cut, diamond]
# 1                       [hanger, bought, closet]
# 2                        [feather, pillow, hard]
# 3    [straight, razor, great, cut, sheet, metal]
# 4          [like, find, orang, tree, antarctica]
# ..                                           ...
# 995      [lamp, convert, peanut, butter, energi]
# 996                        [ride, bicycl, water]
# 997            [boy, wore, uniform, go, restaur]
# 998                         [giraff, drive, car]
# 999                     [use, water, cook, food]
#
#                                 stop_Confusing Reason1  \
# 0    [chainsaw, produc, factori, diamond, deep, gro...
# 1                         [hanger, someth, put, cloth]
# 2                                [feather, come, anim]
# 3                       [straight, razor, made, metal]
# 4                [peopl, take, orang, antarctica, eat]
# ...

# %%
def rejoin_words(row):
    my_list = row['stop_Incorrect Statement']
    joined_words = ( " ".join(my_list))
    return joined_words

file_dev['processed_Incorrect Statement'] = file_dev.apply(rejoin_words, axis=1)
file_dev=file_dev.drop(['stop_Incorrect Statement'], axis = 1)

file_dev
# Out:
#                                 stop_Confusing Reason1  \
# 0    [chainsaw, produc, factori, diamond, deep, gro...
# 1                         [hanger, someth, put, cloth]
# 2                                [feather, come, anim]
# 3                       [straight, razor, made, metal]
# 4                [peopl, take, orang, antarctica, eat]
# ..                                                 ...
# 995               [peanut, energi, food, peopl, light]
# 996                       [water, drink, bicycl, ride]
# 997                            [restaur, alway, crowd]
# 998          [giraff, usual, brown, car, usual, white]
# 999                   [peopl, use, water, start, fire]
#
#                                     stop_Right Reason2  \
# 0                                [diamond, grow, tree]
# 1                                        [hanger, eat]
# 2                             [feather, differ, shape]
# 3             [sheet, metal, lighter, straight, razor]
# ...

# %%
def rejoin_words(row):
    my_list = row['stop_Confusing Reason1']
    joined_words = ( " ".join(my_list))
    return joined_words

file_dev['processed_Confusing Reason1'] = file_dev.apply(rejoin_words, axis=1)
file_dev=file_dev.drop(['stop_Confusing Reason1'], axis = 1)

file_dev
# Out:
#                                     stop_Right Reason2  \
# 0                                [diamond, grow, tree]
# 1                                        [hanger, eat]
# 2                             [feather, differ, shape]
# 3             [sheet, metal, lighter, straight, razor]
# 4    [pile, snow, antarctica, seem, like, orang, tree]
# ..                                                 ...
# 995                         [lamp, look, like, peanut]
# 996                              [imag, water, bicycl]
# 997                           [restaur, sell, uniform]
# 998                                 [giraff, eat, car]
# 999                    [fire, hot, water, cold, gener]
#
#                                 stop_Confusing Reason2  \
# 0                                [diamond, grow, tree]
# 1                                        [hanger, eat]
# 2                             [feather, differ, shape]
# 3             [sheet, metal, lighter, straight, razor]
# ...

# %%
def rejoin_words(row):
    my_list = row['stop_Right Reason2']
    joined_words = ( " ".join(my_list))
    return joined_words

file_dev['processed_Right Reason2'] = file_dev.apply(rejoin_words, axis=1)
file_dev=file_dev.drop(['stop_Right Reason2'], axis = 1)

file_dev
# Out:
#                                 stop_Confusing Reason2  \
# 0                                [diamond, grow, tree]
# 1                                        [hanger, eat]
# 2                             [feather, differ, shape]
# 3             [sheet, metal, lighter, straight, razor]
# 4    [pile, snow, antarctica, seem, like, orang, tree]
# ..                                                 ...
# 995                         [lamp, look, like, peanut]
# 996                              [imag, water, bicycl]
# 997                           [restaur, sell, uniform]
# 998                                 [giraff, eat, car]
# 999                    [fire, hot, water, cold, gener]
#
#                                     stop_Right Reason3  \
# 0                      [chainsaw, arent, use, diamond]
# 1                                [hanger, dont, money]
# 2           [feather, soft, peopl, want, pillow, soft]
# 3    [straight, razor, onli, use, shave, use, cut, ...
# ...

# %%
def rejoin_words(row):
    my_list = row['stop_Confusing Reason2']
    joined_words = ( " ".join(my_list))
    return joined_words

file_dev['processed_Confusing Reason2'] = file_dev.apply(rejoin_words, axis=1)
file_dev=file_dev.drop(['stop_Confusing Reason2'], axis = 1)

file_dev
# Out:
#                                     stop_Right Reason3  \
# 0                      [chainsaw, arent, use, diamond]
# 1                                [hanger, dont, money]
# 2           [feather, soft, peopl, want, pillow, soft]
# 3    [straight, razor, onli, use, shave, use, cut, ...
# 4    [cold, antarctica, orang, tree, requir, tropic...
# ..                                                 ...
# 995          [peanut, butter, eatabl, convert, energi]
# 996                            [bicycl, ridden, water]
# 997                 [restaur, requir, uniform, custom]
# 998            [giraff, could, fit, car, could, navig]
# 999               [water, must, veri, hot, cook, food]
#
#               processed_Correct_sents  \
# 0               chainsaw use cut tree
# 1                   closet got hanger
# 2                         pillow soft
# 3     straight razor great trim beard
# 4        like find orang tree florida
# ..                                ...
# ...

# %%
def rejoin_words(row):
    my_list = row['stop_Right Reason3']
    joined_words = ( " ".join(my_list))
    return joined_words

file_dev['processed_Right Reason3'] = file_dev.apply(rejoin_words, axis=1)
file_dev=file_dev.drop(['stop_Right Reason3'], axis = 1)

file_dev
# Out:
#               processed_Correct_sents  \
# 0               chainsaw use cut tree
# 1                   closet got hanger
# 2                         pillow soft
# 3     straight razor great trim beard
# 4        like find orang tree florida
# ..                                ...
# 995  heat energi convert light energi
# 996                  ride bicycl road
# 997        boy wore uniform go school
# 998                 brother drive car
# 999                use fire cook food
#
#                          processed_Right Reason1  \
# 0               cut diamond chainsaw would break
# 1                 hanger inanim thing buy someth
# 2                             feather alway soft
# 3      blade straight razor thin cut sheet metal
# 4                cold orang tree grow antarctica
# ..                                           ...
# 995  peanut butter directli convert light energi
# 996                    water cant support bicycl
# 997                   peopl wear uniform restaur
# ...

# %%
file_dev.to_csv('file_dev_processed.csv', index=False)
